# %% [markdown]
# <a href="https://colab.research.google.com/github/Gyaniultimate/kaggle_1st_challenge/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1st kaggle competition 
#author : Gyanendra Prakash


import pandas as pd

df = pd.read_csv("train.csv")


L=[[]]
for i in range(df.shape[0]):
  L.append([df.iloc[i]['date'],df.iloc[i]['country']+"_"+df.iloc[i]['store']+"_"+df.iloc[i]['product'],df.iloc[i]['num_sold']])

newdf= pd.DataFrame(L, columns =['date', 'item','sold'])

# %%
newdf.drop(axis=1,index=0,inplace=True)

# %%
newdf
# Out:
#              date                               item    sold
# 1      2015-01-01      Finland_KaggleMart_Kaggle Mug   329.0
# 2      2015-01-01      Finland_KaggleMart_Kaggle Hat   520.0
# 3      2015-01-01  Finland_KaggleMart_Kaggle Sticker   146.0
# 4      2015-01-01      Finland_KaggleRama_Kaggle Mug   572.0
# 5      2015-01-01      Finland_KaggleRama_Kaggle Hat   911.0
# ...           ...                                ...     ...
# 26294  2018-12-31       Sweden_KaggleMart_Kaggle Hat   823.0
# 26295  2018-12-31   Sweden_KaggleMart_Kaggle Sticker   250.0
# 26296  2018-12-31       Sweden_KaggleRama_Kaggle Mug  1004.0
# 26297  2018-12-31       Sweden_KaggleRama_Kaggle Hat  1441.0
# 26298  2018-12-31   Sweden_KaggleRama_Kaggle Sticker   388.0
#
# [26298 rows x 3 columns]

# %%
x_1 = newdf.iloc[0::18,:]
x_1
# Out:
#              date                           item   sold
# 1      2015-01-01  Finland_KaggleMart_Kaggle Mug  329.0
# 19     2015-01-02  Finland_KaggleMart_Kaggle Mug  318.0
# 37     2015-01-03  Finland_KaggleMart_Kaggle Mug  360.0
# 55     2015-01-04  Finland_KaggleMart_Kaggle Mug  332.0
# 73     2015-01-05  Finland_KaggleMart_Kaggle Mug  243.0
# ...           ...                            ...    ...
# 26209  2018-12-27  Finland_KaggleMart_Kaggle Mug  414.0
# 26227  2018-12-28  Finland_KaggleMart_Kaggle Mug  499.0
# 26245  2018-12-29  Finland_KaggleMart_Kaggle Mug  774.0
# 26263  2018-12-30  Finland_KaggleMart_Kaggle Mug  757.0
# 26281  2018-12-31  Finland_KaggleMart_Kaggle Mug  469.0
#
# [1461 rows x 3 columns]

# %%
x_1.reset_index(drop=True, inplace=True)

# %%
ax = x_1.plot(style=".", color="0.8");
moving_average = x_1.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_1['item'].iloc[0], legend=True, );

# %%
import seaborn as sns
sns.heatmap(newdf.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#no null values

# %%
x_1
# Out:
#             date                           item   sold
# 0     2015-01-01  Finland_KaggleMart_Kaggle Mug  329.0
# 1     2015-01-02  Finland_KaggleMart_Kaggle Mug  318.0
# 2     2015-01-03  Finland_KaggleMart_Kaggle Mug  360.0
# 3     2015-01-04  Finland_KaggleMart_Kaggle Mug  332.0
# 4     2015-01-05  Finland_KaggleMart_Kaggle Mug  243.0
# ...          ...                            ...    ...
# 1456  2018-12-27  Finland_KaggleMart_Kaggle Mug  414.0
# 1457  2018-12-28  Finland_KaggleMart_Kaggle Mug  499.0
# 1458  2018-12-29  Finland_KaggleMart_Kaggle Mug  774.0
# 1459  2018-12-30  Finland_KaggleMart_Kaggle Mug  757.0
# 1460  2018-12-31  Finland_KaggleMart_Kaggle Mug  469.0
#
# [1461 rows x 3 columns]

# %%
x_2 = newdf.iloc[1::18,:]
x_2
# Out:
#              date                           item    sold
# 2      2015-01-01  Finland_KaggleMart_Kaggle Hat   520.0
# 20     2015-01-02  Finland_KaggleMart_Kaggle Hat   493.0
# 38     2015-01-03  Finland_KaggleMart_Kaggle Hat   535.0
# 56     2015-01-04  Finland_KaggleMart_Kaggle Hat   544.0
# 74     2015-01-05  Finland_KaggleMart_Kaggle Hat   378.0
# ...           ...                            ...     ...
# 26210  2018-12-27  Finland_KaggleMart_Kaggle Hat   573.0
# 26228  2018-12-28  Finland_KaggleMart_Kaggle Hat   841.0
# 26246  2018-12-29  Finland_KaggleMart_Kaggle Hat  1107.0
# 26264  2018-12-30  Finland_KaggleMart_Kaggle Hat  1113.0
# 26282  2018-12-31  Finland_KaggleMart_Kaggle Hat   822.0
#
# [1461 rows x 3 columns]

# %%
x_2.reset_index(drop=True, inplace=True)

# %%
ax = x_2.plot(style=".", color="0.8");
moving_average = x_2.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_1['item'].iloc[0], legend=True, );

# %%
x_2
# Out:
#             date                           item    sold
# 0     2015-01-01  Finland_KaggleMart_Kaggle Hat   520.0
# 1     2015-01-02  Finland_KaggleMart_Kaggle Hat   493.0
# 2     2015-01-03  Finland_KaggleMart_Kaggle Hat   535.0
# 3     2015-01-04  Finland_KaggleMart_Kaggle Hat   544.0
# 4     2015-01-05  Finland_KaggleMart_Kaggle Hat   378.0
# ...          ...                            ...     ...
# 1456  2018-12-27  Finland_KaggleMart_Kaggle Hat   573.0
# 1457  2018-12-28  Finland_KaggleMart_Kaggle Hat   841.0
# 1458  2018-12-29  Finland_KaggleMart_Kaggle Hat  1107.0
# 1459  2018-12-30  Finland_KaggleMart_Kaggle Hat  1113.0
# 1460  2018-12-31  Finland_KaggleMart_Kaggle Hat   822.0
#
# [1461 rows x 3 columns]

# %%
x_3 = newdf.iloc[2::18,:]
x_3
x_3.reset_index(drop=True, inplace=True)


ax = x_3.plot(style=".", color="0.8");
moving_average = x_3.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_3['item'].iloc[0], legend=True, );

# %%
x_4 = newdf.iloc[3::18,:]
x_4
x_4.reset_index(drop=True, inplace=True)


ax = x_4.plot(style=".", color="0.8");
moving_average = x_4.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_4['item'].iloc[0], legend=True, );

# %%
x_5 = newdf.iloc[4::18,:]
x_5
x_5.reset_index(drop=True, inplace=True)


ax = x_5.plot(style=".", color="0.8");
moving_average = x_5.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_5['item'].iloc[0], legend=True, );

# %%
x_6 = newdf.iloc[5::18,:]

x_6.reset_index(drop=True, inplace=True)


ax = x_6.plot(style=".", color="0.8");
moving_average = x_6.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_6['item'].iloc[0], legend=True, );

# %%
x_7 = newdf.iloc[6::18,:]
x_7
x_7.reset_index(drop=True, inplace=True)


ax = x_7.plot(style=".", color="0.8");
moving_average = x_7.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_7['item'].iloc[0], legend=True, );

# %%
x_8 = newdf.iloc[7::18,:]

x_8.reset_index(drop=True, inplace=True)


ax = x_8.plot(style=".", color="0.8");
moving_average = x_8.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_8['item'].iloc[0], legend=True, );

# %%
x_9 = newdf.iloc[8::18,:]

x_9.reset_index(drop=True, inplace=True)


ax = x_9.plot(style=".", color="0.8");
moving_average = x_9.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_9['item'].iloc[0], legend=True, );

# %%
x_10 = newdf.iloc[9::18,:]

x_10.reset_index(drop=True, inplace=True)


ax = x_10.plot(style=".", color="0.8");
moving_average = x_10.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_10['item'].iloc[0], legend=True, );

# %%
x_11 = newdf.iloc[10::18,:]

x_11.reset_index(drop=True, inplace=True)


ax = x_11.plot(style=".", color="0.8");
moving_average = x_11.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_11['item'].iloc[0], legend=True, );

# %%
x_12 = newdf.iloc[11::18,:]

x_12.reset_index(drop=True, inplace=True)


ax = x_12.plot(style=".", color="0.8");
moving_average = x_12.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_12['item'].iloc[0], legend=True, );

# %%
x_13 = newdf.iloc[12::18,:]

x_13.reset_index(drop=True, inplace=True)


ax = x_13.plot(style=".", color="0.8");
moving_average = x_13.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_13['item'].iloc[0], legend=True, );

# %%
x_14 = newdf.iloc[13::18,:]

x_14.reset_index(drop=True, inplace=True)


ax = x_14.plot(style=".", color="0.8");
moving_average = x_14.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_14['item'].iloc[0], legend=True, );

# %%
x_15 = newdf.iloc[14::18,:]

x_15.reset_index(drop=True, inplace=True)


ax = x_15.plot(style=".", color="0.8");
moving_average = x_15.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_15['item'].iloc[0], legend=True, );

# %%
x_16 = newdf.iloc[15::18,:]

x_16.reset_index(drop=True, inplace=True)


ax = x_16.plot(style=".", color="0.8");
moving_average = x_16.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_16['item'].iloc[0], legend=True, );

# %%
x_17 = newdf.iloc[16::18,:]

x_17.reset_index(drop=True, inplace=True)


ax = x_17.plot(style=".", color="0.8");
moving_average = x_17.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_17['item'].iloc[0], legend=True, );

# %%
x_18 = newdf.iloc[17::18,:]

x_18.reset_index(drop=True, inplace=True)


ax = x_18.plot(style=".", color="0.8");
moving_average = x_18.rolling(     window=100,      center=True,           min_periods=25,  ).mean()             # compute the mean (could also do median, std, min, max, ...)  ax = tunnel.plot(style=".", color="0.5") moving_average.plot(     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False, );

moving_average.plot(    ax=ax,linewidth=3, title=x_18['item'].iloc[0], legend=True, );
